# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sales_data_specifycol=pd.read_csv("Desktop/sales_data_with_discounts.csv",usecols=["Avg Price", "Total Sales Value", "Discount Rate (%)",
       "Discount Amount", "Net Sales Value"])  
b=sales_data_specifycol.head(15)
#calculate barplot for each numeric column
b.plot.bar(column=["Avg Price"],figsize=(10,10));
