# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sales_data_specifycol=pd.read_csv("Desktop/sales_data_with_discounts.csv",usecols=["Avg Price", "Total Sales Value", "Discount Rate (%)",
       "Discount Amount", "Net Sales Value"])
box=sales_data_specifycol.boxplot(column=["Avg Price", "Total Sales Value", "Discount Rate (%)",
       "Discount Amount", "Net Sales Value"],figsize=(12,8))
