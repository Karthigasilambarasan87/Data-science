# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sales_data_specifycol=pd.read_csv("Desktop/sales_data_with_discounts.csv",usecols=["Avg Price", "Total Sales Value", "Discount Rate (%)",
       "Discount Amount", "Net Sales Value"])  
#calculate histogram for each numeric column
#histogram for Average Price
sales_data_specifycol.hist(column='Avg Price');
#histogram for Total Sales Value
sales_data_specifycol.hist(column='Total Sales Value');
#histogram for Discount Rate
sales_data_specifycol.hist(column='Discount Rate (%)');
#histogram for  Discount Amount 
sales_data_specifycol.hist(column='Discount Amount');
#histogram for  Net Sales Value
sales_data_specifycol.hist(column='Net Sales Value');

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
sales_data_specifycol=pd.read_csv("Desktop/sales_data_with_discounts.csv",usecols=["Avg Price", "Total Sales Value", "Discount Rate (%)",
       "Discount Amount", "Net Sales Value"])  
#calculate histogram for each numeric column
sales_data_specifycol.hist(column=["Avg Price", "Total Sales Value", "Discount Rate (%)",
       "Discount Amount", "Net Sales Value"],figsize=(14,14));
